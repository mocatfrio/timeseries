# %% [markdown]
# ## 1. Load and Exploring Data

# %%
data("crqa", package = "crqa")

# %%
typeof(RDts1)
nrow(RDts1)
# Out:
# [1] "list"
# [1] 2000

# %%
head(RDts1)
tail(RDts1)
# Out:
#   V1
# 1 10
# 2  2
# 3  2
# 4 10
# 5 10
# 6 10
#      V1
# 1995 1
# 1996 1
# 1997 1
# 1998 1
# 1999 1
# 2000 1

# %%
barplot(table(RDts1), ylab="Count", col="darkblue")
plot(as.ts(RDts1), col="darkblue", ylab="Position")
# Out:
# plot without title
# plot without title

# %% [markdown]
# ## 2. Preprocessing

# %%
data <- as.matrix(RDts1[1:dim(RDts1)[1],])
head(data)
# Out:
#      [,1]
# [1,] 10
# [2,]  2
# [3,]  2
# [4,] 10
# [5,] 10
# [6,] 10

# %%
seq_1 <- as.matrix(RDts1[1:100,])
seq_2 <- as.matrix(RDts1[101:200,])
seq_3 <- as.matrix(RDts1[201:300,])
data <- cbind(seq_1,seq_2,seq_3)

# %%
head(data)
# Out:
#      [,1] [,2] [,3]
# [1,] 10   5    4
# [2,]  2   5    4
# [3,]  2   5    4
# [4,] 10   5    4
# [5,] 10   5    4
# [6,] 10   5    4

# %%
typeof(data)
# Out:
# [1] "integer"

# %%
lab_1 <- as.matrix(RDts1[2:101,])
lab_2 <- as.matrix(RDts1[102:201,])
lab_3 <- as.matrix(RDts1[202:301,])
labels <- cbind(lab_1,lab_2,lab_3)
